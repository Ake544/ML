# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv('area-price.csv')

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('Area')
plt.ylabel('Price')
plt.scatter(df.area,df.price, color='red', marker='*')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict(np.array(5000).reshape(-1, 1))
# Out:
# c:\Users\ake\Desktop\Just\ML\model\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
d = pd.read_csv('area_to_predict.csv')
d.head(3)
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300

# %%
reg.predict(np.array(d).reshape(-1,1))
# Out:
# c:\Users\ake\Desktop\Just\ML\model\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.16404110e+05, 4.31443936e+07, 3.84297945e+05, 5.23635395e+07,
#        4.92928082e+05, 6.71141728e+07, 6.61304795e+05, 8.99776545e+07,
#        7.40061644e+05, 1.00671864e+08, 7.99808219e+05, 1.08784712e+08,
#        9.26090753e+05, 1.25932323e+08, 6.50441781e+05, 8.85025911e+07,
#        8.25607877e+05, 1.12287987e+08, 4.92928082e+05, 6.71141728e+07,
#        1.40270548e+06, 1.90650727e+08, 1.34839041e+06, 1.83275410e+08,
#        1.14470890e+06, 1.55617973e+08])

# %%
p = reg.predict(np.array(d).reshape(-1,1))
d['Price'] = p
d.to_csv('area_to_predict.csv')
# Out:
# c:\Users\ake\Desktop\Just\ML\model\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# %matplotlib inline
plt.xlabel('Area', fontsize=20)
plt.ylabel('Price', fontsize=20)
plt.scatter(df.area, df.price, color='red', marker='+')
plt.plot(df.area,reg.predict(np.array(df[['area']]).reshape(-1,1)))
# Out:
# c:\Users\ake\Desktop\Just\ML\model\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

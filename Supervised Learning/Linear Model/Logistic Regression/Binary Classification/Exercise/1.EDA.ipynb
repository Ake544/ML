# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('HR_comma_sep.csv')
df.head(3)
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# 2  medium

# %%
df.size
# Out:
# 149990

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %%
df[(df['satisfaction_level'] >= 0.9) & (df['left'] == 1)]
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 7                    0.92             0.85               5
# 67                   0.90             0.98               4
# 99                   0.90             1.00               5
# 106                  0.91             1.00               4
# 113                  0.90             0.96               4
# ...                   ...              ...             ...
# 14789                0.90             0.96               5
# 14938                0.90             0.92               4
# 14947                0.91             0.98               4
# 14985                0.91             0.99               5
# 14987                0.90             0.70               5
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 7                       259                   5              0     1
# 67                      264                   6              0     1
# ...

# %%
df[(df['average_montly_hours'] >= 300) & (df['left'] == 1)]
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 11                   0.11             0.81               6
# 22                   0.09             0.95               6
# 38                   0.11             0.89               6
# 54                   0.10             0.92               7
# 57                   0.10             0.81               6
# ...                   ...              ...             ...
# 14912                0.11             0.80               6
# 14929                0.10             0.83               7
# 14946                0.10             0.84               5
# 14972                0.11             0.97               6
# 14975                0.10             0.79               7
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 11                      305                   4              0     1
# 22                      304                   4              0     1
# ...

# %%
df[(df['number_project'] >= 4) & (df['left'] == 0)]
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 2000                 0.58             0.74               4
# 2002                 0.45             0.69               5
# 2003                 0.78             0.82               5
# 2007                 0.99             0.91               5
# 2008                 0.50             0.75               6
# ...                   ...              ...             ...
# 14198                0.19             0.79               4
# 14201                0.49             0.49               4
# 14204                0.64             0.50               4
# 14207                0.74             0.95               5
# 14210                0.50             0.73               4
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 2000                    215                   3              0     0
# 2002                    193                   3              0     0
# ...

# %%
df[(df['last_evaluation'] <= 0.5) & (df['left'] == 1)]
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 5                    0.41             0.50               2
# 16                   0.45             0.47               2
# 27                   0.40             0.49               2
# 28                   0.41             0.46               2
# 29                   0.38             0.50               2
# ...                   ...              ...             ...
# 14976                0.40             0.47               2
# 14978                0.40             0.47               2
# 14982                0.38             0.49               2
# 14992                0.40             0.48               2
# 14995                0.37             0.48               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 5                       153                   3              0     1
# 16                      160                   3              0     1
# ...

# %%
df['time_spend_company'].max()
# Out:
# np.int64(10)

# %%
for i in range(int(df['time_spend_company'].max())+1):
    left = int(df[(df['time_spend_company'] == i) & (df['left'] == 1)].size)
    total = int(df[(df['time_spend_company'] == i)].size)
    working = total - left
    print(f'#-----Year = {i}-----#')
    print(f'Total: {total}')
    print(f'Working: {total-left}')
    print(f'Left: {left}')
    if total!=0:
        print(f'Leaving Rate:{left/total}')

# %%
df[(df['promotion_last_5years'] == 1) & (df['left'] == 0)].size
# Out:
# 3000

# %%
total = df[(df['Work_accident'] == 1)].size
left = df[(df['Work_accident'] == 1) & (df['left'] == 1)].size  
print(left/total)
total = df[(df['Work_accident'] == 0)].size
left = df[(df['Work_accident'] == 0) & (df['left'] == 1)].size  
print(left/total)
# Out:
# 0.07791609036422315
# 0.2651597817614965

# %%
total = df[(df['promotion_last_5years'] == 1)].size
left = df[(df['promotion_last_5years'] == 1) & (df['left'] == 1)].size
print(left/total)
total = df[(df['promotion_last_5years'] == 0)].size
left = df[(df['promotion_last_5years'] == 0) & (df['left'] == 1)].size
print(left/total)
# Out:
# 0.05956112852664577
# 0.24196185286103541

# %%
df.Department.unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
arr = df.Department.unique()
for i in range(len(arr)-1):
    total = df[arr[i]].size
    left = df[(df[arr[i]]) & df['left']==1]
    if total != 0:
        print(left/total)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ake\Desktop\Just\ML\model\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sales'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[136], line 3
#       1 arr = df.Department.unique()
# ...
